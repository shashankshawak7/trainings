# %%
import pandas as pd

# %%
df=pd.read_csv('completeData.csv',header=0)

# %%
df1=df.loc[df['Date']==4082019]

# %%
df1.reset_index(inplace=True)

# %%
df2=df1.drop(columns=['index','Date'])

# %%
df2.loc[df2['company_name']=='ITC Ltd.']
# Out:
#    company_name  close_diff  voldiff
# 98     ITC Ltd.       -3.05      NaN

# %%
df2.dropna()
# Out:
#                                      company_name  close_diff  voldiff
# 0                              Vodafone Idea Ltd.       -0.30    -0.15
# 1                                   Yes Bank Ltd.       -0.10    -0.18
# 2                 Indiabulls Housing Finance Ltd.      -32.25     0.14
# 3              Zee Entertainment Enterprises Ltd.       -5.35    -0.07
# 4                                Tata Motors Ltd.        1.15    -0.09
# 5                               Bandhan Bank Ltd.      -15.35     0.01
# 6                   Steel Authority of India Ltd.       -1.20    -0.01
# 7                              IndusInd Bank Ltd.      -15.80    -0.08
# 8                             Tata Motors Ltd DVR       -0.50    -0.08
# 9                                  Bank of Baroda       -0.65    -0.09
# 10                                   Vedanta Ltd.       -2.45    -0.06
# 11                         Grasim Industries Ltd.        3.45    -0.08
# ...

# %%
df3=df2.loc[df2['company_name']=='ITC Ltd.']

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [company_name, close_diff, voldiff]
# Index: []

# %%
df3
# Out:
#    company_name  close_diff  voldiff
# 98     ITC Ltd.       -3.05      NaN

# %%
df1=pd.read_csv('NiftyFile.csv')

# %%
df2=pd.read_csv('Volatility')

# %%
df3=pd.merge(df1,df2,on='Symbol')

# %%
df3
# Out:
#                                     Company Name                  Industry  \
# 0                                 ABB India Ltd.  INDUSTRIAL MANUFACTURING
# 1                                       ACC Ltd.  CEMENT & CEMENT PRODUCTS
# 2     Adani Ports and Special Economic Zone Ltd.                  SERVICES
# 3                            Ambuja Cements Ltd.  CEMENT & CEMENT PRODUCTS
# 4                             Ashok Leyland Ltd.                AUTOMOBILE
# 5                              Asian Paints Ltd.            CONSUMER GOODS
# 6                          Aurobindo Pharma Ltd.                    PHARMA
# 7                         Avenue Supermarts Ltd.            CONSUMER GOODS
# 8                                 Axis Bank Ltd.        FINANCIAL SERVICES
# 9                                Bajaj Auto Ltd.                AUTOMOBILE
# 10                            Bajaj Finance Ltd.        FINANCIAL SERVICES
# ...

# %%
df3['Underlying Previous Day Close Price (B)']=pd.to_numeric(df3['Underlying Previous Day Close Price (B)'])

# %%
df3['Underlying Close Price (A)']=pd.to_numeric(df3['Underlying Close Price (A)'])

# %%
df3['closediff']=df3['Underlying Previous Day Close Price (B)']-df3['Underlying Close Price (A)']

# %%
df3
# Out:
#                                     Company Name                  Industry  \
# 0                                 ABB India Ltd.  INDUSTRIAL MANUFACTURING
# 1                                       ACC Ltd.  CEMENT & CEMENT PRODUCTS
# 2     Adani Ports and Special Economic Zone Ltd.                  SERVICES
# 3                            Ambuja Cements Ltd.  CEMENT & CEMENT PRODUCTS
# 4                             Ashok Leyland Ltd.                AUTOMOBILE
# 5                              Asian Paints Ltd.            CONSUMER GOODS
# 6                          Aurobindo Pharma Ltd.                    PHARMA
# 7                         Avenue Supermarts Ltd.            CONSUMER GOODS
# 8                                 Axis Bank Ltd.        FINANCIAL SERVICES
# 9                                Bajaj Auto Ltd.                AUTOMOBILE
# 10                            Bajaj Finance Ltd.        FINANCIAL SERVICES
# ...

# %%
df3['Current Day Underlying Daily Volatility (E) = Sqrt(0.94*D*D + 0.06*C*C)']=pd.to_numeric(df3['Current Day Underlying Daily Volatility (E) = Sqrt(0.94*D*D + 0.06*C*C)'])

# %%
df3['Previous Day Underlying Volatility (D)']=pd.to_numeric(df3['Previous Day Underlying Volatility (D)'])

# %%
df3['voldiff']=df3['Current Day Underlying Daily Volatility (E) = Sqrt(0.94*D*D + 0.06*C*C)']-df3['Previous Day Underlying Volatility (D)']

# %%
df4=df3[['Company Name','Date','closediff','voldiff']]

# %%
dfx=df3[['Company Name','voldiff']]

# %%
dfx
# Out:
#                                     Company Name  voldiff
# 0                                 ABB India Ltd.  -0.0004
# 1                                       ACC Ltd.  -0.0005
# 2     Adani Ports and Special Economic Zone Ltd.  -0.0003
# 3                            Ambuja Cements Ltd.  -0.0002
# 4                             Ashok Leyland Ltd.   0.0046
# 5                              Asian Paints Ltd.   0.0010
# 6                          Aurobindo Pharma Ltd.  -0.0007
# 7                         Avenue Supermarts Ltd.   0.0001
# 8                                 Axis Bank Ltd.  -0.0004
# 9                                Bajaj Auto Ltd.   0.0004
# 10                            Bajaj Finance Ltd.  -0.0008
# 11                            Bajaj Finserv Ltd.  -0.0008
# 12              Bajaj Holdings & Investment Ltd.   0.0024
# 13                             Bandhan Bank Ltd.   0.0001
# 14                                Bank of Baroda  -0.0009
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                                      company_name      Date  close_diff  \
# 0                              Vodafone Idea Ltd.  20042019       -0.70
# 1                                Tata Motors Ltd.  20042019        5.75
# 2                 Indiabulls Housing Finance Ltd.  20042019      -31.90
# 3                             Tata Motors Ltd DVR  20042019        2.45
# 4                                        DLF Ltd.  20042019       -0.25
# 5                                   Yes Bank Ltd.  20042019      -10.65
# 6              Zee Entertainment Enterprises Ltd.  20042019      -13.25
# 7                        InterGlobe Aviation Ltd.  20042019      -27.50
# 8            Hindustan Petroleum Corporation Ltd.  20042019        1.95
# 9                   Steel Authority of India Ltd.  20042019       -1.35
# 10                    Motherson Sumi Systems Ltd.  20042019       -1.05
# 11                                   Vedanta Ltd.  20042019       -6.35
# ...

# %%
dfy=df3[['Company Name','Underlying Previous Day Close Price (B)']]

# %%
dfy['Underlying Previous Day Close Price (B)']=pd.to_numeric(dfy['Underlying Previous Day Close Price (B)'])
# Out:
# /home/shawak/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dfy
# Out:
#                                     Company Name  \
# 0                                 ABB India Ltd.
# 1                                       ACC Ltd.
# 2     Adani Ports and Special Economic Zone Ltd.
# 3                            Ambuja Cements Ltd.
# 4                             Ashok Leyland Ltd.
# 5                              Asian Paints Ltd.
# 6                          Aurobindo Pharma Ltd.
# 7                         Avenue Supermarts Ltd.
# 8                                 Axis Bank Ltd.
# 9                                Bajaj Auto Ltd.
# 10                            Bajaj Finance Ltd.
# 11                            Bajaj Finserv Ltd.
# 12              Bajaj Holdings & Investment Ltd.
# 13                             Bandhan Bank Ltd.
# 14                                Bank of Baroda
# 15                 Bharat Heavy Electricals Ltd.
# 16             Bharat Petroleum Corporation Ltd.
# 17                            Bharti Airtel Ltd.
# ...

# %%
# Out:
# 0       1352.35
# 1       1515.30
# 2        371.10
# 3        196.80
# 4         68.85
# 5       1504.70
# 6        550.60
# 7       1483.35
# 8        669.30
# 9       2537.75
# 10      3222.10
# 11      7081.95
# 12      3354.55
# 13       480.25
# 14       105.55
# 15        57.55
# 16       343.65
# 17       323.90
# 18       250.95
# 19       223.55
# 20     14642.70
# 21      2600.90
# 22       226.30
# 23       512.45
# 24       202.45
# 25      1183.10
# 26       515.45
# 27       172.40
# 28       425.40
# 29      1615.35
#          ...
# 71     18433.45
# 72       235.70
# 73      1211.30
# 74      1765.30
# 75       214.00
# 76     10749.45
# 77      1173.75
# 78       777.00
# 79     20002.20
# 80       967.30
# 81      1119.50
# 82       317.15
# 83        42.10
# 84       425.10
# 85      2180.05
# 86        62.75
# 87       129.55
# 88       419.95
# 89       625.65
# 90       111.55
# 91      1057.20
# 92       576.80
# 93      4231.65
# 94      1402.60
# ...

# %%
dfy.groupby(['Company Name','Underlying Previous Day Close Price (B)']).mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-103-f340d5e373b8> in <module>
# ----> 1 dfy.groupby(['Company Name','Underlying Previous Day Close Price (B)']).mean()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
# ...

# %%
dfy=df[['company_name','closediff']]

# %%
dfy.groupby(['company_name','closediff'])

# %%
dfy['closediff']=pd.to_numeric(df['closediff'])
# Out:
# /home/shawak/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['closediff']=pd.to_numeric(df['closediff'], errors='coerce')

# %%
dfx=df[['company_name','closediff']]

# %%
import numpy as np

# %%
arr=np.array([[1,2,3,4,5,6]]).T

# %%
df=pd.DataFrame(arr)

# %%
df['company_name']=['a','b','c','d','e','f']

# %%
df
# Out:
#    0 company_name
# 0  1            a
# 1  2            b
# 2  3            c
# 3  4            d
# 4  5            e
# 5  6            f

# %%
df.rename(columns={0:'num'},inplace=True)

# %%
df
# Out:
#    num company_name
# 0    1            a
# 1    2            b
# 2    3            c
# 3    4            d
# 4    5            e
# 5    6            f

# %%
df.columns
# Out:
# Index(['num', 'company_name'], dtype='object')

# %%
df.groupby(df['num']).mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-156-d2b704f06a3c> in <module>
# ----> 1 df.groupby(df['num']).mean()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1130         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1131         try:
# -> 1132             return self._cython_agg_general('mean', **kwargs)
#    1133         except GroupByError:
#    1134             raise
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#      68                             min_count=-1):
#      69         new_items, new_blocks = self._cython_agg_blocks(
# ---> 70             how, alt=alt, numeric_only=numeric_only, min_count=min_count)
# ...

# %%
.
