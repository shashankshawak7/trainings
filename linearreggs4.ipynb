# %%
import pandas as pd

# %%
df=pd.read_csv('CMVOLT_15042019.CSV',header=0,usecols=[])

# %%
df.head(1)
# Out:
#           Date     Symbol Underlying Close Price (A)  \
# 0  15-APR-2019  20MICRONS                      38.30
#
#   Underlying Previous Day Close Price (B)  \
# 0                                   38.10
#
#   Underlying Log Returns (C) = LN(A/B) Previous Day Underlying Volatility (D)  \
# 0                               0.0052                                 0.0231
#
#   Current Day Underlying Daily Volatility (E) = Sqrt(0.94*D*D + 0.06*C*C)  \
# 0                                             0.0224
#
#   Underlying Annualised Volatility (F) = E*Sqrt(365)
# 0                                             0.4280

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Underlying Close Price (A)',
#        'Underlying Previous Day Close Price (B)',
#        'Underlying Log Returns (C) = LN(A/B)',
#        'Previous Day Underlying Volatility (D)',
#        'Current Day Underlying Daily Volatility (E) = Sqrt(0.94*D*D + 0.06*C*C)',
#        'Underlying Annualised Volatility (F) = E*Sqrt(365)'],
#       dtype='object')

# %%
df.loc[df['Symbol']=='20MICRONS']
# Out:
#           Date     Symbol Underlying Close Price (A)  \
# 0  15-APR-2019  20MICRONS                      38.30
#
#   Underlying Previous Day Close Price (B)  \
# 0                                   38.10
#
#   Underlying Log Returns (C) = LN(A/B) Previous Day Underlying Volatility (D)  \
# 0                               0.0052                                 0.0231
#
#   Current Day Underlying Daily Volatility (E) = Sqrt(0.94*D*D + 0.06*C*C)  \
# 0                                             0.0224
#
#   Underlying Annualised Volatility (F) = E*Sqrt(365)
# 0                                             0.4280

# %%
df.loc[df['Underlying Close Price (A)']>str(400)]
# Out:
#              Date      Symbol Underlying Close Price (A)  \
# 9     15-APR-2019  AARTIDRUGS                     628.55
# 13    15-APR-2019        ABAN                      58.40
# 15    15-APR-2019  ABBOTINDIA                    7827.10
# 23    15-APR-2019     ACCELYA                     934.50
# 29    15-APR-2019  ADANIPOWER                      54.60
# 33    15-APR-2019  ADHUNIKIND                      60.65
# 34    15-APR-2019      ADLABS                       9.10
# 38    15-APR-2019  ADVANIHOTR                      68.45
# 43    15-APR-2019       AGLSL                      59.20
# 44    15-APR-2019    AGRITECH                      67.60
# 45    15-APR-2019    AGROPHOS                      68.80
# 58    15-APR-2019  ALBERTDAVD                     418.05
# 59    15-APR-2019        ALBK                      53.70
# 61    15-APR-2019  ALEMBICLTD                      42.75
# 62    15-APR-2019      ALICON                     582.00
# ...
